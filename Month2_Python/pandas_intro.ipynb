# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
data = {
    "Name" : ["Anamika", "Pratham", "Kimaya", "Mohit", "Khushi"],
    "Marks" : [90, 78, 77, 69, 85],
    "City" : ["Singapore", "Mumbai", "Dubai", "London", "Venice"]
}

df = pd.DataFrame(data)

df
# Out:
#       Name  Marks       City
# 0  Anamika     90  Singapore
# 1  Pratham     78     Mumbai
# 2   Kimaya     77      Dubai
# 3    Mohit     69     London
# 4   Khushi     85     Venice

# %%
df.head()
# Out:
#       Name  Marks       City
# 0  Anamika     90  Singapore
# 1  Pratham     78     Mumbai
# 2   Kimaya     77      Dubai
# 3    Mohit     69     London
# 4   Khushi     85     Venice

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   Marks   5 non-null      int64
#  2   City    5 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 252.0+ bytes

# %%
df.describe()
# Out:
#            Marks
# count   5.000000
# mean   79.800000
# std     8.043631
# min    69.000000
# 25%    77.000000
# 50%    78.000000
# 75%    85.000000
# max    90.000000

# %%
df["Marks"]
# Out:
# 0    90
# 1    78
# 2    77
# 3    69
# 4    85
# Name: Marks, dtype: int64

# %%
df[["Name", "Marks"]]
# Out:
#       Name  Marks
# 0  Anamika     90
# 1  Pratham     78
# 2   Kimaya     77
# 3    Mohit     69
# 4   Khushi     85

# %%
df[df["Marks"]>75]
# Out:
#       Name  Marks       City
# 0  Anamika     90  Singapore
# 1  Pratham     78     Mumbai
# 2   Kimaya     77      Dubai
# 4   Khushi     85     Venice

# %%
df[df["City"] == "Mumbai"]
# Out:
#       Name  Marks    City
# 1  Pratham     78  Mumbai

# %%
df["Marks"].max()
# Out:
# 90

# %%
df["Marks"].min()
# Out:
# 69

# %%
df["Marks"].mean()
# Out:
# np.float64(79.8)

# %%
df["Marks"].value_counts()
# Out:
# Marks
# 90    1
# 78    1
# 77    1
# 69    1
# 85    1
# Name: count, dtype: int64

# %%
import pandas as pd

# %%
data = {
    "Name": ["Asha", "Rohan", "Meena", "Kunal", "Priya", "Asha"],
    "Marks": [78, None, 90, 55, None, 78],
    "City": ["Pune", "Mumbai", None, "Delhi", "Mumbai", "Pune"]
}

df = pd.DataFrame(data)
df
# Out:
#     Name  Marks    City
# 0   Asha   78.0    Pune
# 1  Rohan    NaN  Mumbai
# 2  Meena   90.0    None
# 3  Kunal   55.0   Delhi
# 4  Priya    NaN  Mumbai
# 5   Asha   78.0    Pune

# %%
df.isnull()
# Out:
#     Name  Marks   City
# 0  False  False  False
# 1  False   True  False
# 2  False  False   True
# 3  False  False  False
# 4  False   True  False
# 5  False  False  False

# %%
df.isnull().sum()
# Out:
# Name     0
# Marks    2
# City     1
# dtype: int64

# %%
df.dropna()
# Out:
#     Name  Marks   City
# 0   Asha   78.0   Pune
# 3  Kunal   55.0  Delhi
# 5   Asha   78.0   Pune

# %%
df["Marks"].fillna(df["Marks"].mean(), inplace=True)
# Out:
# C:\Users\PRATHAMESH\AppData\Local\Temp\ipykernel_18456\1389251290.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Marks"].fillna(df["Marks"].mean(), inplace=True)

# %%
df["City"].fillna("Unknown", inplace=True)
# Out:
# C:\Users\PRATHAMESH\AppData\Local\Temp\ipykernel_18456\4032887332.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["City"].fillna("Unknown", inplace=True)

# %%
df
# Out:
#     Name  Marks     City
# 0   Asha  78.00     Pune
# 1  Rohan  75.25   Mumbai
# 2  Meena  90.00  Unknown
# 3  Kunal  55.00    Delhi
# 4  Priya  75.25   Mumbai
# 5   Asha  78.00     Pune

# %%
df.drop_duplicates()
# Out:
#     Name  Marks     City
# 0   Asha  78.00     Pune
# 1  Rohan  75.25   Mumbai
# 2  Meena  90.00  Unknown
# 3  Kunal  55.00    Delhi
# 4  Priya  75.25   Mumbai

# %%
df = df.drop_duplicates()

# %%
df.columns = df.columns.str.lower()
df
# Out:
#     name  marks     city
# 0   Asha  78.00     Pune
# 1  Rohan  75.25   Mumbai
# 2  Meena  90.00  Unknown
# 3  Kunal  55.00    Delhi
# 4  Priya  75.25   Mumbai

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    5 non-null      object
#  1   marks   5 non-null      float64
#  2   city    5 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 160.0+ bytes
#            marks
# count   5.000000
# mean   74.700000
# std    12.586451
# min    55.000000
# 25%    75.250000
# 50%    75.250000
# 75%    78.000000
# max    90.000000

# %%
#GROUPBY
import pandas as pd
data = {
    "Name": ["Asha", "Rohan", "Meena", "Kunal", "Priya", "Aman"],
    "City": ["Pune", "Mumbai", "Pune", "Delhi", "Mumbai", "Pune"],
    "Marks": [78, 65, 90, 55, 70, 82]
}

df = pd.DataFrame(data)

df
# Out:
#     Name    City  Marks
# 0   Asha    Pune     78
# 1  Rohan  Mumbai     65
# 2  Meena    Pune     90
# 3  Kunal   Delhi     55
# 4  Priya  Mumbai     70
# 5   Aman    Pune     82

# %%
df.groupby("City").mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\PRATHAMESH\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File c:\Users\PRATHAMESH\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Users\PRATHAMESH\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
# ...

# %%
df.groupby("City").count()
# Out:
#         Name  Marks
# City
# Delhi      1      1
# Mumbai     2      2
# Pune       3      3

# %%
df.groupby("City")["Marks"].sum()
# Out:
# City
# Delhi      55
# Mumbai    135
# Pune      250
# Name: Marks, dtype: int64

# %%
df.groupby("City")["Marks"].agg(["mean","max","min","count"])
# Out:
#              mean  max  min  count
# City
# Delhi   55.000000   55   55      1
# Mumbai  67.500000   70   65      2
# Pune    83.333333   90   78      3

# %%
df.groupby("City")["Marks"].mean().sort_values(ascending=False)
# Out:
# City
# Pune      83.333333
# Mumbai    67.500000
# Delhi     55.000000
# Name: Marks, dtype: float64
