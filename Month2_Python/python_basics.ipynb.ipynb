# %%
print("Hi data anlytics world")
# Out:
# Hi data anlytics world

# %%
name = "Medha"
marks = 89

print(name)
print(marks)
# Out:
# Medha
# 89

# %%
age = 20
height = 5.1
city = "Pune"
passed = True

print(type(age))
print(type(height))
print(type(city))
print(type(passed))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
name = "Medha"
marks = 85
city = "Pune"

print(name)
print(marks)
print(city)
# Out:
# Medha
# 85
# Pune

# %%
name = input("Enter your name: ")
print("Hello",name)
# Out:
# Enter your name:  Pratima
# Hello Pratima

# %%
marks = int(input("Enter your marks: "))
print("Your marks are: ",marks)
# Out:
# Enter your marks:  99
# Your marks are:  99

# %%
a = 10
b = 4

print(a + b)
print(a / b)
print(a - b)
print(a * b)
print(a % b)
# Out:
# 14
# 2.5
# 6
# 40
# 2

# %%
marks1 = int(input("Enter marks1: "))
marks2 = int(input("Enter marks2: "))

total = marks1 + marks2
average = total / 2

print("Total marks are: ",total)
print("Average maks are: ",average)
# Out:
# Enter marks1:  20
# Enter marks2:  19
# Total marks are:  39
# Average maks are:  19.5

# %%
marks = 75

if marks >= 60:
    print("Pass")
# Out:
# Pass

# %%
marks = 55
if marks>=60:
    print("Pass")
else:
    print("Fail")
# Out:
# Fail

# %%
marks = 67
if marks>=85:
    print("Excellent")
elif marks>=70:
    print("Good")
elif marks>=60:
    print("Average")
else:
    print("Needs improvement")
# Out:
# Average

# %%
marks = int(input("Enter your marks: "))

if marks >= 85:
    print("Excellent")
elif marks >= 70:
    print("Good")
elif marks >= 60:
    print("Average")
else:
    print("Needs improvement")
# Out:
# Enter your marks:  43
# Needs improvement

# %%
sales = int(input("Enter month;y sales: "))

if sales >= 1000000:
    print("High performance")
elif sales >= 500000:
    print("Average performance")
else:
    print("Low performance")
# Out:
# Enter month;y sales:  7056888
# High performance

# %%
for i in range(3):
    print("Hello, World!!!!")
# Out:
# Hello, World!!!!
# Hello, World!!!!
# Hello, World!!!!

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(1, 6):
    print("Student", i)
# Out:
# Student 1
# Student 2
# Student 3
# Student 4
# Student 5

# %%
total = 0
for i in range(1, 6):
    total += i

print("Total: ", total)
# Out:
# Total:  15

# %%
i = 0
while i <= 5:
    print(i)
    i+=1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
total = 0

for i in range(5):
    marks = int(input("Enter marks: "))
    total += marks

average = total / 5
print("Average marks: ", average)
# Out:
# Enter marks:  67
# Enter marks:  55
# Enter marks:  43
# Enter marks:  88
# Enter marks:  90
# Average marks:  68.6
