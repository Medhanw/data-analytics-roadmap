# %%
print("Hello Data Analytics World")
# Out:
# Hello Data Analytics World

# %%
name = "Medha"
marks = 88

print(name)
print(marks)
# Out:
# Medha
# 88

# %%
age = 20
height = 5.1
city = "Pune"
passed = True

print(type(age))
print(type(height))
print(type(city))
print(type(passed))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
